# %% [markdown]
# [about groupby](ch10.ipynb#Grouping-with-Dicts-and-Series)

# %% [markdown]
# ## with_group_keys
# [Group keys appear as indexs](ch10.ipynb#@with_group_keys)
# - Some details to help yourself recognize the cell

# %% [markdown]
# ## example_1
# [ID without special characters](ch10.ipynb#example_1)
