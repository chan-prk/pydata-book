# %% [markdown]
# # Python Language Basics, IPython, and Jupyter Notebooks

# %%
import numpy as np
np.random.seed(12345)
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# ## The Python Interpreter

# %% [markdown]
# ```python
# $ python
# Python 3.6.0 | packaged by conda-forge | (default, Jan 13 2017, 23:17:12)
# [GCC 4.8.2 20140120 (Red Hat 4.8.2-15)] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>> a = 5
# >>> print(a)
# 5
# ```

# %% [markdown]
# ```python
# print('Hello world')
# ```

# %% [markdown]
# ```python
# $ python hello_world.py
# Hello world
# ```

# %% [markdown]
# ```shell
# $ ipython
# Python 3.6.0 | packaged by conda-forge | (default, Jan 13 2017, 23:17:12)
# Type "copyright", "credits" or "license" for more information.
#
# IPython 5.1.0 -- An enhanced Interactive Python.
# ?         -> Introduction and overview of IPython's features.
# %quickref -> Quick reference.
# help      -> Python's own help system.
# object?   -> Details about 'object', use 'object??' for extra details.
#
# In [1]: %run hello_world.py
# Hello world
#
# In [2]:
# ```

# %% [markdown]
# ## IPython Basics

# %% [markdown]
# ### Running the IPython Shell

# %% [markdown]
# $

# %%
import numpy as np
data = {i : np.random.randn() for i in range(7)}
data
# Out:
# {0: 0.163237556162501,
#  1: -0.37040882274338893,
#  2: -0.08088067273179514,
#  3: -0.9098779171581127,
#  4: 0.25760185356933984,
#  5: 0.5749282673553658,
#  6: -0.8597249109794647}

# %% [markdown]
# >>> from numpy.random import randn
# >>> data = {i : randn() for i in range(7)}
# >>> print(data)
# {0: -1.5948255432744511, 1: 0.10569006472787983, 2: 1.972367135977295,
# 3: 0.15455217573074576, 4: -0.24058577449429575, 5: -1.2904897053651216,
# 6: 0.3308507317325902}

# %% [markdown]
# #### Print in Ipython vs. in Python interpreter
#
# ![](chan_folder/print_ipython.png)
# ![](chan_folder/print_interpreter.png)

# %% [markdown]
# ### Running the Jupyter Notebook

# %% [markdown]
# ```shell
# $ jupyter notebook
# [I 15:20:52.739 NotebookApp] Serving notebooks from local directory:
# /home/wesm/code/pydata-book
# [I 15:20:52.739 NotebookApp] 0 active kernels
# [I 15:20:52.739 NotebookApp] The Jupyter Notebook is running at:
# http://localhost:8888/
# [I 15:20:52.740 NotebookApp] Use Control-C to stop this server and shut down
# all kernels (twice to skip confirmation).
# Created new window in existing browser session.
# ```

# %% [markdown]
# ### Tab Completion

# %% [markdown]
# ```
# In [1]: an_apple = 27
#
# In [2]: an_example = 42
#
# In [3]: an
# ```

# %% [markdown]
# ```
# In [3]: b = [1, 2, 3]
#
# In [4]: b.
# ```

# %% [markdown]
# ```
# In [1]: import datetime
#
# In [2]: datetime.
# ```

# %% [markdown]
# ```
# In [7]: datasets/movielens/
# ```

# %% [markdown]
# From book (page 22)
# ```
# In [7]: path = 'datasets/movielens/<Tab>
# datasets/movielens/movies.dat datasets/movielens/README
# datasets/movielens/ratings.dat datasets/movielens/users.dat
# ```
# ![](chan_folder/tab_datasets.png)

# %%
path = 'datasets/movielens/users.dat'

# %%
# For completion of function keyword-arguments
def func_with_keywords(abra=1, abbra=2, abbbra=3):
    return abra, abbra, abbbra

# %%
func_with_keywords(abbbra=30)
# Out:
# (1, 2, 30)

# %% [markdown]
# ### Introspection

# %% [markdown]
# ```
# In [8]: b = [1, 2, 3]
#
# In [9]: b?
# Type:       list
# String Form:[1, 2, 3]
# Length:     3
# Docstring:
# list() -> new empty list
# list(iterable) -> new list initialized from iterable's items
#
# In [10]: print?
# Docstring:
# print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
# Prints the values to a stream, or to sys.stdout by default.
# Optional keyword arguments:
# file:  a file-like object (stream); defaults to the current sys.stdout.
# sep:   string inserted between values, default a space.
# end:   string appended after the last value, default a newline.
# flush: whether to forcibly flush the stream.
# Type:      builtin_function_or_method
# ```

# %% [markdown]
# ```python
# def add_numbers(a, b):
#     """
#     Add two numbers together
#
#     Returns
#     -------
#     the_sum : type of arguments
#     """
#     return a + b
# ```

# %% [markdown]
# ```python
# In [11]: add_numbers?
# Signature: add_numbers(a, b)
# Docstring:
# Add two numbers together
#
# Returns
# -------
# the_sum : type of arguments
# File:      <ipython-input-9-6a548a216e27>
# Type:      function
# ```

# %% [markdown]
# ```python
# In [12]: add_numbers??
# Signature: add_numbers(a, b)
# Source:
# def add_numbers(a, b):
#     """
#     Add two numbers together
#
#     Returns
#     -------
#     the_sum : type of arguments
#     """
#     return a + b
# File:      <ipython-input-9-6a548a216e27>
# Type:      function
# ```

# %%
def add_numbers(a, b):
    """
    Add two numbers together

    Returns
    -------
    the_sum : type of arguments
    """
    return a + b

# %%
add_numbers?

# %% [markdown]
# ```python
# In [13]: np.*load*?
# np.__loader__
# np.load
# np.loads
# np.loadtxt
# np.pkgload
# ```

# %%
np.*load*?

# %% [markdown]
# ### The %run Command

# %% [markdown]
# **From book** The script is run in an empty namespace (with no imports or other variables defined)
# so that the behavior should be identical to running the program on the command line
# using `python script.py`.

# %% [markdown]
# ```python
# def f(x, y, z):
#     return (x + y) / z
#
# a = 5
# b = 6
# c = 7.5
#
# result = f(a, b, c)
# ```

# %% [markdown]
# ```python
# In [14]: %run ipython_script_test.py
# ```

# %% [markdown]
# **From book** All of the variables (imports, functions, and globals)
# defined in the file (up until an exception, if any, is raised) will then be accessible in
# the IPython shell:

# %% [markdown]
# ```python
# In [15]: c
# Out [15]: 7.5
#
# In [16]: result
# Out[16]: 1.4666666666666666
# ```

# %% [markdown]
# ```python
# >>> %load ipython_script_test.py
#
#     def f(x, y, z):
#         return (x + y) / z
#
#     a = 5
#     b = 6
#     c = 7.5
#
#     result = f(a, b, c)
# ```

# %% [markdown]
# #### Interrupting running code

# %% [markdown]
# ### Executing Code from the Clipboard

# %% [markdown]
# ```python
# x = 5
# y = 7
# if x > 5:
#     x += 1
#
#     y = 8
# ```

# %% [markdown]
# ```python
# In [17]: %paste
# x = 5
# y = 7
# if x > 5:
#     x += 1
#
#     y = 8
# ## -- End pasted text --
# ```

# %% [markdown]
# ```python
# In [18]: %cpaste
# Pasting code; enter '--' alone on the line to stop or use Ctrl-D.
# :x = 5
# :y = 7
# :if x > 5:
# :    x += 1
# :
# :    y = 8
# :--
# ```

# %% [markdown]
# ![](chan_folder/cpaste.png)

# %% [markdown]
# ### Terminal Keyboard Shortcuts

# %% [markdown]
# ### About Magic Commands

# %% [markdown]
# ```python
# In [20]: a = np.random.randn(100, 100)
#
# In [20]: %timeit np.dot(a, a)
# 10000 loops, best of 3: 20.9 µs per loop
# ```

# %% [markdown]
# ```python
# In [21]: %debug?
# Docstring:
# ::
#
#   %debug [--breakpoint FILE:LINE] [statement [statement ...]]
#
# Activate the interactive debugger.
#
# This magic command support two ways of activating debugger.
# One is to activate debugger before executing code.  This way, you
# can set a break point, to step through the code from the point.
# You can use this mode by giving statements to execute and optionally
# a breakpoint.
#
# The other one is to activate debugger in post-mortem mode.  You can
# activate this mode simply running %debug without any argument.
# If an exception has just occurred, this lets you inspect its stack
# frames interactively.  Note that this will always work only on the last
# traceback that occurred, so you must call this quickly after an
# exception that you wish to inspect has fired, because if another one
# occurs, it clobbers the previous one.
#
# If you want IPython to automatically do this on every exception, see
# the %pdb magic for more details.
#
# positional arguments:
#   statement             Code to run in debugger. You can omit this in cell
#                         magic mode.
#
# optional arguments:
#   --breakpoint <FILE:LINE>, -b <FILE:LINE>
#                         Set break point at LINE in FILE.
#
# ```

# %%
# %debug?

# %% [markdown]
# ```python
# In [22]: %pwd
# Out[22]: '/home/wesm/code/pydata-book
#
# In [23]: foo = %pwd
#
# In [24]: foo
# Out[24]: '/home/wesm/code/pydata-book'
# ```

# %% [markdown]
# ### Matplotlib Integration

# %% [markdown]
# ```python
# In [26]: %matplotlib
# Using matplotlib backend: Qt4Agg
# ```

# %% [markdown]
# ```python
# In [26]: %matplotlib inline
# ```

# %% [markdown]
# ## Python Language Basics

# %% [markdown]
# ### Language Semantics

# %% [markdown]
# #### Indentation, not braces

# %% [markdown]
# ```python
# for x in array:
#     if x < pivot:
#         less.append(x)
#     else:
#         greater.append(x)
# ```

# %% [markdown]
# ```python
# a = 5; b = 6; c = 7
# ```

# %% [markdown]
# #### Everything is an object

# %% [markdown]
# #### Comments

# %% [markdown]
# ```python
# results = []
# for line in file_handle:
#     # keep the empty lines for now
#     # if len(line) == 0:
#     #   continue
#     results.append(line.replace('foo', 'bar'))
# ```

# %% [markdown]
# ```python
# print("Reached this line")  # Simple status report
# ```

# %% [markdown]
# #### Function and object method calls

# %% [markdown]
# ```
# result = f(x, y, z)
# g()
# ```

# %% [markdown]
# ```
# obj.some_method(x, y, z)
# ```

# %% [markdown]
# ```python
# result = f(a, b, c, d=5, e='foo')
# ```

# %% [markdown]
# #### Variables and argument passing
# *important*

# %%
a = [1, 2, 3]

# %%
b = a

# %%
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# *terminology* ตัวแปร a และ b เรียกว่า references
# ![](chan_folder/two_references.png)

# %%
def append_element(some_list, element):
    some_list.append(element)

# %%
data = [1, 2, 3]
append_element(data, 4)
data
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ```python
# def append_element(some_list, element):
#     some_list.append(element)
# ```

# %% [markdown]
# ```python
# In [27]: data = [1, 2, 3]
#
# In [28]: append_element(data, 4)
#
# In [29]: data
# Out[29]: [1, 2, 3, 4]
# ```

# %% [markdown]
# #### Dynamic references, strong types

# %%
a = 5
type(a)
a = 'foo'
type(a)

# %%
'5' + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-4dd8efb5fac1> in <module>
# ----> 1 '5' + 5
#
# TypeError: must be str, not int

# %% [markdown]
# In some languages, such as Visual Basic, the string '5' might get implicitly converted
# (or casted) to an integer, thus yielding 10. Yet in other languages, such as JavaScript,
# the integer 5 might be casted to a string, yielding the concatenated string '55'.

# %% [markdown]
# In this regard Python is considered a strongly typed language, which means that every object
# has a specific type (or class), and implicit conversions will occur only in certain obvious
# circumstances, such as the following:

# %%
a = 4.5
b = 2
# String formatting, to be visited later
print('a is {0}, b is {1}'.format(type(a), type(b)))
a / b
# Out:
# a is <class 'float'>, b is <class 'int'>
# 2.25

# %%
a = 5
isinstance(a, int)
# Out:
# True

# %% [markdown]
# isinstance can accept a tuple of types if you want to check that an object’s type is
# among those present in the tuple:

# %%
a = 5; b = 4.5
isinstance(a, (int, float))
isinstance(b, (int, float))
# Out:
# True

# %% [markdown]
# #### Attributes and methods
#
# Objects in Python typically have both attributes (other Python objects stored “inside”
# the object) and methods (functions associated with an object that can have access to
# the object’s internal data). Both of them are accessed via the syntax
# obj.attribute_name:

# %% [markdown]
# ```python
# In [1]: a = 'foo'
#
# In [2]: a.<Press Tab>
# a.capitalize  a.format      a.isupper     a.rindex      a.strip
# a.center      a.index       a.join        a.rjust       a.swapcase
# a.count       a.isalnum     a.ljust       a.rpartition  a.title
# a.decode      a.isalpha     a.lower       a.rsplit      a.translate
# a.encode      a.isdigit     a.lstrip      a.rstrip      a.upper
# a.endswith    a.islower     a.partition   a.split       a.zfill
# a.expandtabs  a.isspace     a.replace     a.splitlines
# a.find        a.istitle     a.rfind       a.startswith
# ```

# %% [markdown]
# #search

# %%
a = 'f,o,o'

# %%
spl = getattr(a, 'split')

# %%
a.split(",")
# Out:
# ['f', 'o', 'o']

# %%
spl(',') # object a is assumed already.
# Out:
# ['f', 'o', 'o']

# %%
str.split(a, ",")
# Out:
# ['f', 'o', 'o']

# %% [markdown]
# #### Duck typing

# %% [markdown]
# Often you may not care about the type of an object but rather only whether it has
# certain methods or behavior. This is sometimes called “duck typing,” after the saying
# “If it walks like a duck and quacks like a duck, then it’s a duck.”
#
#
# For example, you can
# verify that an object is iterable if it implemented the iterator protocol. For many
# objects, this means it has a `__iter__` “magic method,” though an alternative and better
# way to check is to try using the iter function:

# %%
def isiterable(obj):
    try:
        iter(obj)
        return True
    except TypeError: # not iterable
        return False

# %%
isiterable('a string')
isiterable([1, 2, 3])
isiterable(5)

# %% [markdown]
# A common case is writing a function that can accept any
# kind of sequence (list, tuple, ndarray) or even an iterator. You can first check if the
# object is a list (or a NumPy array) and, if it is not, convert it to be one:
#
# ```
# if not isinstance(x, list) and isiterable(x):
#     x = list(x)
# ```

# %% [markdown]
# #### Imports

# %% [markdown]
# ```python
# # some_module.py
# PI = 3.14159
#
# def f(x):
#     return x + 2
#
# def g(a, b):
#     return a + b
# ```

# %%
from chan_folder import some_module
result = some_module.f(5)
pi = some_module.PI

# %%
from chan_folder.some_module import f, g, PI
result = g(5, PI)

# %%
import chan_folder.some_module as sm
from chan_folder.some_module import PI as pi, g as gf

r1 = sm.f(pi)
r2 = gf(6, pi)

print(f"{r1} and {r2}")
# Out:
# 5.14159 and 9.14159

# %%
# from chan_folder.some_module import f # อันนี้เวิร์ค
import chan_folder.some_module.f
f(8)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-83-d97c83cc8cb3> in <module>
#       1 # from chan_folder.some_module import f # อันนี้เวิร์ค
# ----> 2 import chan_folder.some_module.f
#       3 f(8)
#
# ModuleNotFoundError: No module named 'chan_folder.some_module.f'; 'chan_folder.some_module' is not a package

# %% [markdown]
# #### Binary operators and comparisons

# %%
5 - 7
12 + 21.5
5 <= 2

# %%
a = [1, 2, 3]
b = a
c = list(a)
print(a is b)
print(a is not c)
# Out:
# True
# True

# %% [markdown]
# Since list always creates a new Python list (i.e., a copy), we can be sure that `c` is distinct
# from `a`. Comparing with is is not the same as the `==` operator, because in this
# case we have:

# %%
a == c
# Out:
# True

# %%
a = None
a is None
# Out:
# True

# %% [markdown]
# #### Mutable and immutable objects

# %%
a_list = ['foo', 2, [4, 5]]
a_list[2] = (3, 4)
a_list
# Out:
# ['foo', 2, (3, 4)]

# %%
a_tuple = (3, 5, (4, 5))
a_tuple[1] = 'four'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-2c9bddc8679c> in <module>
#       1 a_tuple = (3, 5, (4, 5))
# ----> 2 a_tuple[1] = 'four'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Remember that just because you can mutate an object does not mean that you always
# should. Such actions are known as **side effects**. For example, when writing a function,
# any side effects should be explicitly communicated to the user in the function’s documentation
# or comments. If possible, I recommend trying to avoid side effects and
# favor immutability, even though there may be mutable objects involved.

# %% [markdown]
# ### Scalar Types

# %% [markdown]
# #### Numeric types

# %%
ival = 17239871
ival ** 6

# %%
fval = 7.243
fval2 = 6.78e-5

# %%
3 / 2
# Out:
# 1.5

# %%
3 // 2 # floor division operator
# Out:
# 1

# %% [markdown]
# #### Strings

# %% [markdown]
# You can write string literals using either single quotes ' or double quotes ":
#
# ```
# a = 'one way of writing a string'
# b = "another way"
# ```

# %%
c = """
This is a longer string that
spans multiple lines
"""

# %% [markdown]
# string c actually contains four lines of text; the line
# breaks after """ and after `lines` are included in the string. We can count the new line
# characters with the count method on c:

# %%
c.count('\n')
# Out:
# 3

# %%
a = 'this is a string'
a[10] = 'f'
b = a.replace('string', 'longer string')
b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-85038afe6a01> in <module>
#       1 a = 'this is a string'
# ----> 2 a[10] = 'f'
#       3 b = a.replace('string', 'longer string')
#       4 b
#
# TypeError: 'str' object does not support item assignment

# %%
b = a.replace('string', 'longer string')
b
# Out:
# 'this is a longer string'

# %% [markdown]
# `a` is unmodified

# %%
a
# Out:
# 'this is a string'

# %%
a = 5.6
s = str(a)
print(s)
# Out:
# 5.6

# %% [markdown]
# สมมติเราต้องการดึงข้อมูลถึงตัวที่ 3 นั่นก็คือ ตัวที่ 4 จะถูก excluded ออกไป เราก้เลยใช้ index ของตัวที่ 4 (ซึ่งคือ 3) เป็นตัวหลังใน slice notation = [:3]

# %%
s = 'python'
list(s)
s[:3] # 3 คือ index ของตัว h ซึ่งเป็นตัวที่ 4
# Out:
# 'pyt'

# %% [markdown]
# To write a string literal with
# backslashes, you need to escape them:

# %%
s = '12\\34'
print(s)
print(f"{s[1]}, {s[2]}, {s[3]}")
# Out:
# 12\34
# 2, \, 3

# %%
# หมายความว่า \ here ไม่ถูก ตีความเป็น escape character เวลาสร้าง string 
# หรือก็คือ literal หลัง r (which means 'raw') ถูกเอาไปใช้เป็น string แบบดิบๆ ไม่ผ่านการปรุง
s = r'this\has\no\special\characters' 
s
# Out:
# 'this\\has\\no\\special\\characters'

# %%
# ผลที่ได้ก็คือ string ผลลัพธ์ กับ เหมือนกับ literal ที่ตามหลัง r
print(s)
# Out:
# this\has\no\special\characters

# %%
a = 'this is the first half '
b = 'and this is the second half'
a + b
# Out:
# 'this is the first half and this is the second half'

# %%
template = '{0:.2f} {1:s} are worth US${2:d}'
print(template)
# Out:
# {0:.2f} {1:s} are worth US${2:d}

# %%
template.format(4.5560, 'Argentine Pesos', 1)
# Out:
# '4.56 Argentine Pesos are worth US$1'

# %% [markdown]
# #### Bytes and Unicode

# %%
val = "español"
val
# Out:
# 'español'

# %%
type(val)
# Out:
# str

# %% [markdown]
# We can convert this **Unicode string** to its UTF-8 bytes representation using the
# encode method:

# %%
val_utf8 = val.encode('utf-8')
val_utf8
type(val_utf8)
# Out:
# bytes

# %%
val_utf8.decode('utf-8')
# Out:
# 'español'

# %%
val.encode('latin1')
val.encode('utf-16')
val.encode('utf-16le')

# %%
bytes_val = b'this is bytes'
bytes_val
decoded = bytes_val.decode('utf8')
decoded  # this is str (Unicode) now

# %% [markdown]
# #####  My experiment
# #search

# %%
bytecode = b'espa\xc3\xb1ol'
decoded = bytecode.decode('utf8')
decoded
# Out:
# 'español'

# %%
letter = '汉'
letter
# Out:
# '汉'

# %%
letter.encode('utf-8')
# Out:
# b'\xe6\xb1\x89'

# %%
b'\xe6\xb1\x89'.decode('utf8')
# Out:
# '汉'

# %%
def bytes_to_binary_string(bytes_data):
    """
    Converts a bytes object to its binary string representation.
    Each byte is represented by an 8-bit binary string, padded with leading zeros.
    """
    return ''.join(f'{byte:08b}' for byte in bytes_data)

# Example usage:
my_bytes = letter.encode('utf-8') # b'\xe6\xb1\x89'
binary_representation = bytes_to_binary_string(my_bytes)
print(binary_representation)
# From https://gist.github.com/guocheng/1ae6c2d76461a66cfc5ec6009b5791d1
# https://nbviewer.org/gist/guocheng/1ae6c2d76461a66cfc5ec6009b5791d1
print('111001101011000110001001')
# Out:
# 111001101011000110001001
# 111001101011000110001001

# %%
print(f'{ord("汉"):016b}')
print(f'{ord("汉"):16b}') # pad ด้วยช่องว่าง
print(f'{1:08b}')
print(f'{1:8b}')
# Out:
# 0110110001001001
#  110110001001001
# 00000001
#        1

# %%
print(my_bytes)
list(byte for byte in my_bytes)
# Out:
# b'\xe6\xb1\x89'
# [230, 177, 137]

# %%
b'\xf1'[0]
# Out:
# 241

# %%
15*16+1
# Out:
# 241

# %%
b'Hello'[4]
# Out:
# 111

# %% [markdown]
# #### Booleans

# %%
True and True
False or True

# %% [markdown]
# #### Type casting

# %%
s = '3.14159'
fval = float(s)
type(fval)
int(fval)
bool(fval)
bool(0)

# %% [markdown]
# #### None

# %%
a = None
a is None
b = 5
b is not None

# %% [markdown]
# None is the Python null value type. If a function does not explicitly return a value, it
# implicitly returns None:

# %%
def void():
    x = 1

print(void())
# Out:
# None

# %% [markdown]
# def add_and_maybe_multiply(a, b, c=None):
#     result = a + b
#
#     if c is not None:
#         result = result * c
#
#     return result

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# #### Dates and times

# %%
from datetime import datetime, date, time
dt = datetime(2011, 10, 29, 20, 30, 21)
dt.day
dt.minute
# Out:
# 30

# %%
dt.date()
dt.time()
# Out:
# datetime.time(20, 30, 21)

# %%
dt.strftime('%m/%d/%Y %H:%M')

# %%
datetime.strptime('20091031', '%Y%m%d')
# Out:
# datetime.datetime(2009, 10, 31, 0, 0)

# %%
dt.replace(minute=0, second=10) # ถ้า second เป็น 0 จะไม่โชว์
# Out:
# datetime.datetime(2011, 10, 29, 20, 0, 10)

# %%
dt2 = datetime(2011, 11, 15, 22, 30)
delta = dt2 - dt
delta
# Out:
# datetime.timedelta(17, 7179)

# %%
type(delta)
# Out:
# datetime.timedelta

# %%
dt
dt + delta
# Out:
# datetime.datetime(2011, 11, 15, 22, 30)

# %% [markdown]
# ### Control Flow

# %% [markdown]
# #### if, elif, and else

# %% [markdown]
# if x < 0:
#     print('It's negative')

# %% [markdown]
# if x < 0:
#     print('It's negative')
# elif x == 0:
#     print('Equal to zero')
# elif 0 < x < 5:
#     print('Positive but smaller than 5')
# else:
#     print('Positive and larger than or equal to 5')

# %%
a = 5; b = 7
c = 8; d = 4
if a < b or c > d:
    print('Made it') #short-circuit: c > d never gets evaluated
# Out:
# Made it

# %%
4 > 3 > 2 > 1
# Out:
# True

# %% [markdown]
# #### for loops

# %% [markdown]
# for value in collection:
#     # do something with value

# %%
sequence = [1, 2, None, 4, None, 5]
total = 0
for value in sequence:
    if value is None:
        continue
    total += value
print(total)
# Out:
# 12

# %%
sequence = [1, 2, 0, 4, 6, 5, 2, 1]
total_until_5 = 0
for value in sequence:
    if value == 5:
        break
    total_until_5 += value
print(total_until_5)
# Out:
# 13

# %%
for i in range(4):
    for j in range(4):
        if j > i:
            break
        print((i, j))
# Out:
# (0, 0)
# (1, 0)
# (1, 1)
# (2, 0)
# (2, 1)
# (2, 2)
# (3, 0)
# (3, 1)
# (3, 2)
# (3, 3)

# %% [markdown]
# As we will see in more detail, if the elements in the collection or iterator are sequences
# (tuples or lists, say), they can be conveniently **unpacked** into variables in the for
# loop statement:

# %% [markdown]
# ```
# for a, b, c in iterator:
#     # do something
# ```

# %%
# My experiment
print(list(range(4))) # 4 เป็น index ของ ตัวที่ 5 ใน seq เมื่อเรา exclude ตัวนี้ ก็จะแปลว่าเราเอาตั้งแต่ตัวแรกถึงตัวที่ 4(index 3)
# Out:
# [0, 1, 2, 3]

# %% [markdown]
# #### while loops

# %% [markdown]
# x = 256
# total = 0
# while x > 0:
#     if total > 500:
#         break
#     total += x
#     x = x // 2

# %% [markdown]
# #### pass

# %%
x = 2.7
if x < 0:
    print('negative!')
elif x == 0:
    pass
else:
    print('positive!')
# Out:
# positive!

# %%
# it is only required because Python uses whitespace to delimit blocks:
x = 2.7
if x < 0:
    print('negative!')
elif x == 0:
else:
    print('positive!')
# Out:
#   File "<ipython-input-175-348841734a4d>", line 6
#     else:
#        ^
# IndentationError: expected an indented block

# %% [markdown]
# #### range

# %%
range(10)
list(range(10))

# %%
list(range(0, 20, 2))
list(range(5, 0, -1)) # 5 เป็น index ของตัวที่ 6 ถูก included ไปจนถึงตัวที่ 2 (ตัวที่ 1 ถูก excluded เพราะ index เป็น 0)
# Out:
# [5, 4, 3, 2, 1]

# %%
x = '00011100' # เอา ตั้งแต่ตัวที่ 4 สามตัวติดกัน
print(x[3:6]) # ตัวที่ 4 index คือ 3 และ exclude ที่ตัวที่ 4 + 3 = 7 ซึ่ง index คือ 6
# Out:
# 111

# %%
seq = [1, 2, 3, 4]
for i in range(len(seq)): #len = 4 เป็น index ของตัวที่ 5 ถ้าเรา exclude มันก็เท่ากับเอา 4 ตัว
    val = seq[i]
    print(val)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ```
# sum = 0
# for i in range(100000):
#     # % is the modulo operator
#     if i % 3 == 0 or i % 5 == 0:
#         sum += i
# ```
# While the range generated can be arbitrarily large, the memory use at any given time
# may be very small.

# %% [markdown]
# #### Ternary expressions

# %% [markdown]
# value =

# %% [markdown]
# if

# %%
x = 5
'Non-negative' if x >= 0 else 'Negative'
# Out:
# 'Non-negative'
