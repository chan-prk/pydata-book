# %%
a = 1
b = 1
a is b
# Out:
# True

# %%
a = [1]
b = [1]
a is b
# Out:
# False

# %%
x = ([1,1],[2,2])
y = x*2
print(y)
y[2] is x[0]
# Out:
# ([1, 1], [2, 2], [1, 1], [2, 2])
# True

# %%
x = ([1,1],[2,2],[2,2])
y = x*5
print(y)
print(y[12] is x[0]) #12 = 0 mod 3
print(y[10] is x[1]) #10 = 1 mod 3
# Out:
# ([1, 1], [2, 2], [2, 2], [1, 1], [2, 2], [2, 2], [1, 1], [2, 2], [2, 2], [1, 1], [2, 2], [2, 2], [1, 1], [2, 2], [2, 2])
# True
# True

# %%
import numpy as np
import pandas as pd

pd.DataFrame([[1, 2], [10, 20], [100, 200]])
# Out:
#      0    1
# 0    1    2
# 1   10   20
# 2  100  200

# %%
pd.DataFrame(zip([1, 10, 100], [2, 20, 200]))
# Out:
#      0    1
# 0    1    2
# 1   10   20
# 2  100  200

# %%
pd.DataFrame(np.array([[1, 2], [10, 20], [100, 200]]))
# Out:
#      0    1
# 0    1    2
# 1   10   20
# 2  100  200

# %%
import pandas as pd

pd.DataFrame([{'a': [1, 2, 3]}]) 
# label ของ dict อยากให้มันเป็น row label แต่มันเป็น col label
# สาเหตุที่อยากเพราะ อยากลอง implement groupby.mean() from scratch 
# เพราะคิดว่าสามารถสร้าง pair ของ name + processed_group ซึ่งคาดหวังว่า ถ้าสามารถจับมันใส่ {pair: processed_group} แล้วเอามาต่อๆกัน
# ก่อนป้อนเข้า instructor ของ DataFrame ได้ก็คงดี
# Out:
#            a
# 0  [1, 2, 3]

# %%
pd.DataFrame([{'a': 1, 'b': 2, 'c': 3}])
# Out:
#    a  b  c
# 0  1  2  3

# %%
pd.DataFrame({'a': {'one': [1, 2, 3]}}) # สิ่งที่อยากให้เป็น row ถูกบังคับให้อยู่ใน column a ทั้งหมด ทำให้ไม่แยกตัวเป็นหนึ่ง row ที่มีหลายๆคอลัมน์
# Out:
#              a
# one  [1, 2, 3]
