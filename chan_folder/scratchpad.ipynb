# %%
a = 1
b = 1
a is b
# Out:
# True

# %%
a = [1]
b = [1]
a is b
# Out:
# False

# %%
x = ([1,1],[2,2])
y = x*2
print(y)
y[2] is x[0]
# Out:
# ([1, 1], [2, 2], [1, 1], [2, 2])
# True

# %%
x = ([1,1],[2,2],[2,2])
y = x*5
print(y)
print(y[12] is x[0]) #12 = 0 mod 3
print(y[10] is x[1]) #10 = 1 mod 3
# Out:
# ([1, 1], [2, 2], [2, 2], [1, 1], [2, 2], [2, 2], [1, 1], [2, 2], [2, 2], [1, 1], [2, 2], [2, 2], [1, 1], [2, 2], [2, 2])
# True
# True
